# %%
from dfs0 import dfs0

# %% [markdown]
#  The output data is `pandas DataFrame`, and the column of `Time` format is Datetime.
#  This demo data is the MIKE pile scour tool outputs.

# %%
filename = 'dfs0 FilePath'
dfs0_obj = dfs0(filename)
dfs0_obj.dfs0_read()
# Out:
#                     Time  Scour Depth  Direction of Max. Scour Width [d  \
# 0    2017-01-01 02:00:00     0.034506                             180.0
# 1    2017-01-01 03:00:00     0.066143                             180.0
# 2    2017-01-01 04:00:00     0.095151                             180.0
# 3    2017-01-01 05:00:00     0.121748                             180.0
# 4    2017-01-01 06:00:00     0.146134                             180.0
# 5    2017-01-01 07:00:00     0.168494                             180.0
# 6    2017-01-01 08:00:00     0.188994                             180.0
# 7    2017-01-01 09:00:00     0.207791                             180.0
# 8    2017-01-01 10:00:00     0.225025                             180.0
# 9    2017-01-01 11:00:00     0.240827                             180.0
# 10   2017-01-01 12:00:00     0.255316                             180.0
# 11   2017-01-01 13:00:00     0.268600                             180.0
# ...
